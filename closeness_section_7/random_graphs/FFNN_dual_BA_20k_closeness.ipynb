# %% [markdown]
# # Learning the closeness centrality of a real world graph using the $p$-aggregation of the RCDF matrix representation of nodes

# %%
from mygraph import MyGraph
from helpers import *
import time

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

# %% [markdown]
# ## Loading the dataset from numpy files

# %%
# closeness centrality of the first graph as the target or label data
target_closeness1 = np.load("dual_BA_20K_1_closeness.npy", mmap_mode=None, allow_pickle=False, fix_imports=True, encoding='ASCII')
target_closeness1[0]
# Out:
# array([0.31004279])

# %%
target_closeness1.shape
# Out:
# (20000, 1)

# %% [markdown]
# ## Loading the RCDF  matrix as a numpy array

# %%
# the RCDF matrix of the first graph as the feature set
matrix1 = np.load("dual_BA_20K_1_RDFC_matrix.npy", mmap_mode=None, allow_pickle=False, fix_imports=True, encoding='ASCII')

# %%
matrix1.shape
# Out:
# (20000, 2, 21)

# %%
matrix1[121]
# Out:
# array([[ 2.,  3.,  9.,  1.,  4.,  3.,  1.,  1.,  1.,  1.,  1.,  0.,  2.,
#          1.,  0.,  0.,  0.,  0.,  0.,  0.,  1.],
#        [61., 21., 93., 58., 66., 41., 17., 25., 13., 15., 11.,  3.,  5.,
#          6.,  5.,  0.,  2.,  0.,  0.,  1.,  3.]])

# %% [markdown]
# # The p-aggregation of the RCDF matrix
#
# To apply this aggregation we just need to multiply the following row matrix from left to the RCDF matrix:
# ### $$
# \left[ 1, p, p^2, \cdots, p^{(r -1 )} \right],
# $$
# where $r$ is the order of the RCDF matrix representation (the number of rows).

# %%
p = 0.2
order = matrix1.shape[1]
parameter_vector = np.zeros(order)
for i in range(order):
    parameter_vector[i] += p**i
parameter_vector
# Out:
# array([1. , 0.2])

# %%
res_matrix = np.matmul(parameter_vector, matrix1)
res_matrix.shape
# Out:
# (20000, 21)

# %%
res_matrix[121]
# Out:
# array([14.2,  7.2, 27.6, 12.6, 17.2, 11.2,  4.4,  6. ,  3.6,  4. ,  3.2,
#         0.6,  3. ,  2.2,  1. ,  0. ,  0.4,  0. ,  0. ,  0.2,  1.6])

# %% [markdown]
# # Converting the dataset into pytorch tensors

# %%
features = torch.from_numpy(res_matrix)
targets = torch.from_numpy(target_closeness1)
features.shape, targets.shape
# Out:
# (torch.Size([20000, 21]), torch.Size([20000, 1]))

# %%
# Activating the automatic gradient 
features.requires_grad_(True)
targets.requires_grad_(True)
# Out:
# tensor([[0.3100],
#         [0.3022],
#         [0.2597],
#         ...,
#         [0.2122],
#         [0.1760],
#         [0.1809]], dtype=torch.float64, requires_grad=True)

# %%
# Shuffling and dividing the indecies
n_samples = features.shape[0]
n_test = 10000
shuffled_ind = torch.randperm(n_samples)
train_ind = shuffled_ind[:-n_test]
test_ind = shuffled_ind[-n_test:]
# Dividing features and targets into tain and test sets
train_features = features[train_ind]
test_features = features[test_ind]
train_targets = targets[train_ind]
test_targets = targets[test_ind]
train_features.shape, test_features.shape, train_targets.shape, test_targets.shape
# Out:
# (torch.Size([10000, 21]),
#  torch.Size([10000, 21]),
#  torch.Size([10000, 1]),
#  torch.Size([10000, 1]))

# %% [markdown]
# ## A function for dividing train data into batches

# %%
# dividing train_features and train_targets into batches
def next_batch(train_features, train_targets, batch_size=100):
    num_features = train_features.shape[0]
    # Shuffling
    shuffled_ind = torch.randperm(num_features)
    shuffled_train_features = train_features[shuffled_ind]
    shuffled_train_targets = train_targets[shuffled_ind]
    # Dividing
    i = 0
    while i < num_features:
        i += batch_size
        yield (shuffled_train_features[i-batch_size:i], shuffled_train_targets[i-batch_size:i])
    return

# %% [markdown]
# ## The feedforward neural network model

# %%
# The Feedforward Neural Network 
class FFNN_model(nn.Module):
    def __init__(self):
        super().__init__()
        num_features = features.shape[1]
        self.fc1 = nn.Linear(num_features, 64)
        self.fc2 = nn.Linear(64, 8)
        self.fc3 = nn.Linear(8, 1)
        self.dropout1 = nn.Dropout(0.3)
        
    def forward(self, X):
        X = torch.tanh(self.fc1(X))
        X = self.dropout1(X)
        X = torch.relu(self.fc2(X))
        return self.fc3(X)

# %%
# Instantiation of the model
torch.manual_seed(42)
model = FFNN_model()
model
# Out:
# FFNN_model(
#   (fc1): Linear(in_features=21, out_features=64, bias=True)
#   (fc2): Linear(in_features=64, out_features=8, bias=True)
#   (fc3): Linear(in_features=8, out_features=1, bias=True)
#   (dropout1): Dropout(p=0.3, inplace=False)
# )

# %%
num_para = 0
for param in model.parameters():
    print(param.numel())
    num_para += param.numel()
print("----------------------")
print(f'Number of all parameters: \n{num_para}')
# Out:
# 1344
# 64
# 512
# 8
# 8
# 1
# ----------------------
# Number of all parameters:
# 1937

# %%
# Objective function and optimizer
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=1e-3)
# optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

# %% [markdown]
# ## Defining the Training Loop

# %%
def training_loop(n_epochs=1000,
                  batch_size=100,
                  optimizer=optimizer, 
                  model=model, 
                  loss_fn=criterion, 
                  train_features=train_features, 
                  test_features=test_features, 
                  train_targets=train_targets, 
                  test_targets=test_targets):
    num_features = train_features.shape[0]
    start_time = time.time()
    all_train_loss, all_test_loss = np.zeros(n_epochs), np.zeros(n_epochs)
    for epoch in range(1, n_epochs +1):
        # Training: 
        epoch_losses = []
        # looping through batches
        for train_features, train_targets in next_batch(train_features=train_features, 
                                                        train_targets=train_targets, batch_size=batch_size): 
            train_preds = model(train_features.float())
            train_loss = loss_fn(train_targets.float(), train_preds.float())
            optimizer.zero_grad()
            train_loss.backward(retain_graph=True)
            optimizer.step()
            
            epoch_losses.append(train_loss.item())
        average_epoch_loss = sum(epoch_losses)/len(epoch_losses)
        
        # Test:
        with torch.no_grad():
            test_preds = model(test_features.float())
            test_loss = loss_fn(test_targets.float(), test_preds.float())
        
        all_train_loss[epoch - 1] = average_epoch_loss
        all_test_loss[epoch - 1] = test_loss.item()
        # Printing the result: 
        if epoch == 1 or epoch % 100 == 0:
            print(f"EPOCH: {epoch:{7}}")
            print(f"MEAN TRAIN LOSS:   {average_epoch_loss:.11f},    Test LOSS:   {test_loss.item():.11f}")
            print("-----------------------------------------")
    print("The total time = ", np.round(time.time() - start_time, 3), " seconds!")
    return all_train_loss, all_test_loss

# %% [markdown]
# # Training the model

# %%
losses = training_loop(n_epochs=2000,
                  batch_size=400,
                  optimizer=optimizer, 
                  model=model, 
                  loss_fn=criterion, 
                  train_features=train_features, 
                  test_features=test_features, 
                  train_targets=train_targets, 
                  test_targets=test_targets)
# Out:
# EPOCH:       1
# MEAN TRAIN LOSS:   0.00660361515,    Test LOSS:   0.00330327265
# -----------------------------------------
# EPOCH:     100
# MEAN TRAIN LOSS:   0.00067688688,    Test LOSS:   0.00069015572
# -----------------------------------------
# EPOCH:     200
# MEAN TRAIN LOSS:   0.00033057071,    Test LOSS:   0.00029267647
# -----------------------------------------
# EPOCH:     300
# MEAN TRAIN LOSS:   0.00016865108,    Test LOSS:   0.00017619619
# -----------------------------------------
# EPOCH:     400
# MEAN TRAIN LOSS:   0.00011467274,    Test LOSS:   0.00011847387
# -----------------------------------------
# EPOCH:     500
# MEAN TRAIN LOSS:   0.00007863306,    Test LOSS:   0.00009142506
# -----------------------------------------
# EPOCH:     600
# MEAN TRAIN LOSS:   0.00006212524,    Test LOSS:   0.00007080169
# -----------------------------------------
# EPOCH:     700
# MEAN TRAIN LOSS:   0.00005583291,    Test LOSS:   0.00006047572
# -----------------------------------------
# EPOCH:     800
# MEAN TRAIN LOSS:   0.00005067866,    Test LOSS:   0.00005400850
# -----------------------------------------
# EPOCH:     900
# MEAN TRAIN LOSS:   0.00004284582,    Test LOSS:   0.00005089563
# -----------------------------------------
# EPOCH:    1000
# MEAN TRAIN LOSS:   0.00004007055,    Test LOSS:   0.00004858195
# -----------------------------------------
# EPOCH:    1100
# MEAN TRAIN LOSS:   0.00004200812,    Test LOSS:   0.00004439990
# -----------------------------------------
# EPOCH:    1200
# MEAN TRAIN LOSS:   0.00003305278,    Test LOSS:   0.00004345555
# -----------------------------------------
# EPOCH:    1300
# MEAN TRAIN LOSS:   0.00003457324,    Test LOSS:   0.00004095391
# -----------------------------------------
# EPOCH:    1400
# MEAN TRAIN LOSS:   0.00003055908,    Test LOSS:   0.00003833939
# -----------------------------------------
# EPOCH:    1500
# MEAN TRAIN LOSS:   0.00002835299,    Test LOSS:   0.00003636182
# -----------------------------------------
# EPOCH:    1600
# MEAN TRAIN LOSS:   0.00002502796,    Test LOSS:   0.00003606865
# -----------------------------------------
# EPOCH:    1700
# MEAN TRAIN LOSS:   0.00002638093,    Test LOSS:   0.00003567177
# -----------------------------------------
# EPOCH:    1800
# MEAN TRAIN LOSS:   0.00002771837,    Test LOSS:   0.00003278604
# -----------------------------------------
# EPOCH:    1900
# MEAN TRAIN LOSS:   0.00002294797,    Test LOSS:   0.00003114824
# -----------------------------------------
# EPOCH:    2000
# MEAN TRAIN LOSS:   0.00002169155,    Test LOSS:   0.00003089517
# -----------------------------------------
# The total time =  142.901  seconds!

# %%
model.eval()
errors1 = []
for i in range(n_test):
    targ = targets[i].item()
    feat = features[i].float().view(1,1,21)
    pred = model(feat).item()
    inaccuracy = abs(1 - pred/targ) * 100
    errors1.append(inaccuracy)
    if i%100 == 0:
        print(f"target {targ},    prediction: {pred}\nindex {i}:       inaccuracy: {np.round(inaccuracy, 3)}%")
        print("-----------------------------------")
print("Average inaccuracy on the test set of the first graph: ", np.round(sum(errors1)/len(errors1), 3))
# Out:
# target 0.3100427880441523,    prediction: 0.25735872983932495
# index 0:       inaccuracy: 16.993%
# -----------------------------------
# target 0.2147105556987031,    prediction: 0.21515420079231262
# index 100:       inaccuracy: 0.207%
# -----------------------------------
# target 0.24471990406500085,    prediction: 0.2433473765850067
# index 200:       inaccuracy: 0.561%
# -----------------------------------
# target 0.23233848763316564,    prediction: 0.23336240649223328
# index 300:       inaccuracy: 0.441%
# -----------------------------------
# target 0.2443849744604932,    prediction: 0.24472856521606445
# index 400:       inaccuracy: 0.141%
# -----------------------------------
# target 0.20762003633532314,    prediction: 0.20937180519104004
# index 500:       inaccuracy: 0.844%
# -----------------------------------
# target 0.21246600373958865,    prediction: 0.21197843551635742
# index 600:       inaccuracy: 0.229%
# -----------------------------------
# target 0.2182129646804657,    prediction: 0.21598786115646362
# index 700:       inaccuracy: 1.02%
# -----------------------------------
# target 0.21515637271250443,    prediction: 0.21263770759105682
# index 800:       inaccuracy: 1.171%
# -----------------------------------
# target 0.21460226845940059,    prediction: 0.2143273651599884
# index 900:       inaccuracy: 0.128%
# -----------------------------------
# target 0.21875239272393163,    prediction: 0.21994200348854065
# index 1000:       inaccuracy: 0.544%
# -----------------------------------
# target 0.21040062281698438,    prediction: 0.21019472181797028
# index 1100:       inaccuracy: 0.098%
# -----------------------------------
# target 0.2265097630589408,    prediction: 0.22713695466518402
# index 1200:       inaccuracy: 0.277%
# -----------------------------------
# target 0.2208199454547462,    prediction: 0.2221190333366394
# index 1300:       inaccuracy: 0.588%
# -----------------------------------
# target 0.23482651323900663,    prediction: 0.2377179116010666
# index 1400:       inaccuracy: 1.231%
# -----------------------------------
# target 0.21990939279980648,    prediction: 0.21986986696720123
# index 1500:       inaccuracy: 0.018%
# -----------------------------------
# target 0.23341503267973857,    prediction: 0.23313921689987183
# index 1600:       inaccuracy: 0.118%
# -----------------------------------
# target 0.20418393808833438,    prediction: 0.20800043642520905
# index 1700:       inaccuracy: 1.869%
# -----------------------------------
# target 0.19051747132568686,    prediction: 0.19676309823989868
# index 1800:       inaccuracy: 3.278%
# -----------------------------------
# target 0.2093127917442907,    prediction: 0.20935511589050293
# index 1900:       inaccuracy: 0.02%
# -----------------------------------
# target 0.20003600828190485,    prediction: 0.20084793865680695
# index 2000:       inaccuracy: 0.406%
# -----------------------------------
# target 0.18552464354295575,    prediction: 0.18169796466827393
# index 2100:       inaccuracy: 2.063%
# -----------------------------------
# target 0.19307222227585608,    prediction: 0.19652311503887177
# index 2200:       inaccuracy: 1.787%
# -----------------------------------
# target 0.2053306502120145,    prediction: 0.20779065787792206
# index 2300:       inaccuracy: 1.198%
# -----------------------------------
# target 0.22083457558993386,    prediction: 0.2253081202507019
# index 2400:       inaccuracy: 2.026%
# -----------------------------------
# target 0.21218873009304942,    prediction: 0.2096969038248062
# index 2500:       inaccuracy: 1.174%
# -----------------------------------
# target 0.20528006733522886,    prediction: 0.2029014527797699
# index 2600:       inaccuracy: 1.159%
# -----------------------------------
# target 0.17260456044050887,    prediction: 0.17000353336334229
# index 2700:       inaccuracy: 1.507%
# -----------------------------------
# target 0.18023124825392248,    prediction: 0.17509007453918457
# index 2800:       inaccuracy: 2.853%
# -----------------------------------
# target 0.17700579722972076,    prediction: 0.1775895357131958
# index 2900:       inaccuracy: 0.33%
# -----------------------------------
# target 0.17891393809268205,    prediction: 0.17030474543571472
# index 3000:       inaccuracy: 4.812%
# -----------------------------------
# target 0.18728285807931824,    prediction: 0.19255253672599792
# index 3100:       inaccuracy: 2.814%
# -----------------------------------
# target 0.22788286235186872,    prediction: 0.23162607848644257
# index 3200:       inaccuracy: 1.643%
# -----------------------------------
# target 0.19912975943922256,    prediction: 0.1992688924074173
# index 3300:       inaccuracy: 0.07%
# -----------------------------------
# target 0.1927800269905533,    prediction: 0.19396325945854187
# index 3400:       inaccuracy: 0.614%
# -----------------------------------
# target 0.16566160269047894,    prediction: 0.17178219556808472
# index 3500:       inaccuracy: 3.695%
# -----------------------------------
# target 0.2029036970902155,    prediction: 0.2000846564769745
# index 3600:       inaccuracy: 1.389%
# -----------------------------------
# target 0.22753285169804882,    prediction: 0.2283262312412262
# index 3700:       inaccuracy: 0.349%
# -----------------------------------
# target 0.21894398038163845,    prediction: 0.21750305593013763
# index 3800:       inaccuracy: 0.658%
# -----------------------------------
# target 0.19822186099988107,    prediction: 0.2004006803035736
# index 3900:       inaccuracy: 1.099%
# -----------------------------------
# target 0.17699326506951757,    prediction: 0.17461857199668884
# index 4000:       inaccuracy: 1.342%
# -----------------------------------
# target 0.1843378713441668,    prediction: 0.17817506194114685
# index 4100:       inaccuracy: 3.343%
# -----------------------------------
# target 0.19928651858937949,    prediction: 0.19793644547462463
# index 4200:       inaccuracy: 0.677%
# -----------------------------------
# target 0.1679275860042152,    prediction: 0.17134958505630493
# index 4300:       inaccuracy: 2.038%
# -----------------------------------
# target 0.2320608029705268,    prediction: 0.23560920357704163
# index 4400:       inaccuracy: 1.529%
# -----------------------------------
# target 0.18452326031997934,    prediction: 0.18218894302845
# index 4500:       inaccuracy: 1.265%
# -----------------------------------
# target 0.18290987579798423,    prediction: 0.187228724360466
# index 4600:       inaccuracy: 2.361%
# -----------------------------------
# target 0.20308501563832812,    prediction: 0.20330581068992615
# index 4700:       inaccuracy: 0.109%
# -----------------------------------
# target 0.22942789294359234,    prediction: 0.23191241919994354
# index 4800:       inaccuracy: 1.083%
# -----------------------------------
# target 0.19318412333491108,    prediction: 0.19373807311058044
# index 4900:       inaccuracy: 0.287%
# -----------------------------------
# target 0.20182051204424126,    prediction: 0.20248806476593018
# index 5000:       inaccuracy: 0.331%
# -----------------------------------
# target 0.18456072351421188,    prediction: 0.174993634223938
# index 5100:       inaccuracy: 5.184%
# -----------------------------------
# target 0.1669588592800374,    prediction: 0.16925814747810364
# index 5200:       inaccuracy: 1.377%
# -----------------------------------
# target 0.1739754508364288,    prediction: 0.1714126169681549
# index 5300:       inaccuracy: 1.473%
# -----------------------------------
# target 0.2195014871969356,    prediction: 0.2194003313779831
# index 5400:       inaccuracy: 0.046%
# -----------------------------------
# target 0.1779033047191211,    prediction: 0.1761261224746704
# index 5500:       inaccuracy: 0.999%
# -----------------------------------
# target 0.19440097205346293,    prediction: 0.1971983015537262
# index 5600:       inaccuracy: 1.439%
# -----------------------------------
# target 0.1949334269060569,    prediction: 0.1985461711883545
# index 5700:       inaccuracy: 1.853%
# -----------------------------------
# target 0.20557971237960135,    prediction: 0.20316645503044128
# index 5800:       inaccuracy: 1.174%
# -----------------------------------
# target 0.20521055655885734,    prediction: 0.20519663393497467
# index 5900:       inaccuracy: 0.007%
# -----------------------------------
# target 0.20846623720474494,    prediction: 0.20590585470199585
# index 6000:       inaccuracy: 1.228%
# -----------------------------------
# target 0.20519792329318093,    prediction: 0.20497454702854156
# index 6100:       inaccuracy: 0.109%
# -----------------------------------
# target 0.20873168287897131,    prediction: 0.20852798223495483
# index 6200:       inaccuracy: 0.098%
# -----------------------------------
# target 0.22887126492029158,    prediction: 0.22990535199642181
# index 6300:       inaccuracy: 0.452%
# -----------------------------------
# target 0.1883712606435084,    prediction: 0.18784664571285248
# index 6400:       inaccuracy: 0.279%
# -----------------------------------
# target 0.19663926689215763,    prediction: 0.1999472975730896
# index 6500:       inaccuracy: 1.682%
# -----------------------------------
# target 0.14875338430870846,    prediction: 0.16156214475631714
# index 6600:       inaccuracy: 8.611%
# -----------------------------------
# target 0.184173205142373,    prediction: 0.18597808480262756
# index 6700:       inaccuracy: 0.98%
# -----------------------------------
# target 0.20101113657379488,    prediction: 0.20193925499916077
# index 6800:       inaccuracy: 0.462%
# -----------------------------------
# target 0.21312942931741888,    prediction: 0.2152559906244278
# index 6900:       inaccuracy: 0.998%
# -----------------------------------
# target 0.17519162542157593,    prediction: 0.17607198655605316
# index 7000:       inaccuracy: 0.503%
# -----------------------------------
# target 0.20188570678672738,    prediction: 0.20378068089485168
# index 7100:       inaccuracy: 0.939%
# -----------------------------------
# target 0.19180565279522763,    prediction: 0.1951405107975006
# index 7200:       inaccuracy: 1.739%
# -----------------------------------
# target 0.16649877201015692,    prediction: 0.1631391942501068
# index 7300:       inaccuracy: 2.018%
# -----------------------------------
# target 0.2064071998431227,    prediction: 0.2070593237876892
# index 7400:       inaccuracy: 0.316%
# -----------------------------------
# target 0.1498389151120102,    prediction: 0.16183826327323914
# index 7500:       inaccuracy: 8.008%
# -----------------------------------
# target 0.20737030930828174,    prediction: 0.2019076943397522
# index 7600:       inaccuracy: 2.634%
# -----------------------------------
# target 0.17784635085503908,    prediction: 0.18002484738826752
# index 7700:       inaccuracy: 1.225%
# -----------------------------------
# target 0.20483642993219575,    prediction: 0.20243890583515167
# index 7800:       inaccuracy: 1.17%
# -----------------------------------
# target 0.2000080007200648,    prediction: 0.19838835299015045
# index 7900:       inaccuracy: 0.81%
# -----------------------------------
# target 0.18834110279229646,    prediction: 0.1835508942604065
# index 8000:       inaccuracy: 2.543%
# -----------------------------------
# target 0.19984810784343116,    prediction: 0.19965243339538574
# index 8100:       inaccuracy: 0.098%
# -----------------------------------
# target 0.2332163306240015,    prediction: 0.2351161241531372
# index 8200:       inaccuracy: 0.815%
# -----------------------------------
# target 0.15894297635605006,    prediction: 0.1648421585559845
# index 8300:       inaccuracy: 3.712%
# -----------------------------------
# target 0.1779967246965004,    prediction: 0.17600548267364502
# index 8400:       inaccuracy: 1.119%
# -----------------------------------
# target 0.19206353779519242,    prediction: 0.1971113085746765
# index 8500:       inaccuracy: 2.628%
# -----------------------------------
# target 0.1962340797142689,    prediction: 0.19407431781291962
# index 8600:       inaccuracy: 1.101%
# -----------------------------------
# target 0.20394240378536027,    prediction: 0.1999732255935669
# index 8700:       inaccuracy: 1.946%
# -----------------------------------
# target 0.18037592221801324,    prediction: 0.17662087082862854
# index 8800:       inaccuracy: 2.082%
# -----------------------------------
# target 0.19171555657808964,    prediction: 0.19486874341964722
# index 8900:       inaccuracy: 1.645%
# -----------------------------------
# target 0.18103229777681223,    prediction: 0.18178200721740723
# index 9000:       inaccuracy: 0.414%
# -----------------------------------
# target 0.16260671599317017,    prediction: 0.16394782066345215
# index 9100:       inaccuracy: 0.825%
# -----------------------------------
# target 0.17066177411784786,    prediction: 0.17288637161254883
# index 9200:       inaccuracy: 1.304%
# -----------------------------------
# target 0.20202030405576038,    prediction: 0.19918715953826904
# index 9300:       inaccuracy: 1.402%
# -----------------------------------
# target 0.18095858555697314,    prediction: 0.1829414814710617
# index 9400:       inaccuracy: 1.096%
# -----------------------------------
# target 0.20168618078036285,    prediction: 0.20002365112304688
# index 9500:       inaccuracy: 0.824%
# -----------------------------------
# target 0.18642914406100267,    prediction: 0.18045540153980255
# index 9600:       inaccuracy: 3.204%
# -----------------------------------
# target 0.21252244880609544,    prediction: 0.2145802527666092
# index 9700:       inaccuracy: 0.968%
# -----------------------------------
# target 0.2098200702932382,    prediction: 0.2094395011663437
# index 9800:       inaccuracy: 0.181%
# -----------------------------------
# target 0.21650265770300844,    prediction: 0.2173977494239807
# index 9900:       inaccuracy: 0.413%
# -----------------------------------
# Average inaccuracy on the test set of the first graph:  1.42

# %% [markdown]
# # Testing the model on the second random graph

# %%
matrix2 = np.load("dual_BA_20K_2_RDFC_matrix.npy", mmap_mode=None, allow_pickle=False, fix_imports=True, encoding='ASCII')

# %%
# closeness centrality as the target or label data
target_closeness2 = np.load("dual_BA_20K_2_closeness.npy", mmap_mode=None, allow_pickle=False, fix_imports=True, encoding='ASCII')
target_closeness2[0]
# Out:
# array([0.31145269])

# %%
res_matrix2 = np.matmul(parameter_vector, matrix2)
res_matrix2.shape
# Out:
# (20000, 21)

# %% [markdown]
# # Converting the dataset of the second graph into pytorch tensors

# %%
features2 = torch.from_numpy(res_matrix2)
targets2 = torch.from_numpy(target_closeness2)
features2.shape, targets2.shape
# Out:
# (torch.Size([20000, 21]), torch.Size([20000, 1]))

# %%
model.eval()
errors2 = []
for i in range(20000):
    targ = targets2[i].item()
    feat = features2[i].float().view(1,1,21)
    pred = model(feat).item()
    inaccuracy = abs(1 - pred/targ) * 100
    errors2.append(inaccuracy)
    if i%100 == 0:
        print(f"target {targ},    prediction: {pred}\nindex {i}:       inaccuracy: {np.round(inaccuracy, 3)}%")
        print("-----------------------------------")
print("Average inaccuracy on the second graph: ", np.round(sum(errors2)/len(errors2), 3))
# Out:
# target 0.31145268797109577,    prediction: 0.25239336490631104
# index 0:       inaccuracy: 18.963%
# -----------------------------------
# target 0.24238567913803344,    prediction: 0.23839102685451508
# index 100:       inaccuracy: 1.648%
# -----------------------------------
# target 0.23819108644386747,    prediction: 0.23959751427173615
# index 200:       inaccuracy: 0.59%
# -----------------------------------
# target 0.2253510017352895,    prediction: 0.22863270342350006
# index 300:       inaccuracy: 1.456%
# -----------------------------------
# target 0.19863925307906238,    prediction: 0.20285996794700623
# index 400:       inaccuracy: 2.125%
# -----------------------------------
# target 0.22347248916104231,    prediction: 0.22532951831817627
# index 500:       inaccuracy: 0.831%
# -----------------------------------
# target 0.20671869347253088,    prediction: 0.2130400389432907
# index 600:       inaccuracy: 3.058%
# -----------------------------------
# target 0.23089800725055995,    prediction: 0.2323492467403412
# index 700:       inaccuracy: 0.629%
# -----------------------------------
# target 0.2055691466398043,    prediction: 0.20497730374336243
# index 800:       inaccuracy: 0.288%
# -----------------------------------
# target 0.20980246110592407,    prediction: 0.20930492877960205
# index 900:       inaccuracy: 0.237%
# -----------------------------------
# target 0.21665745826427033,    prediction: 0.21906675398349762
# index 1000:       inaccuracy: 1.112%
# -----------------------------------
# target 0.21135006605019815,    prediction: 0.21241293847560883
# index 1100:       inaccuracy: 0.503%
# -----------------------------------
# target 0.22615372437267475,    prediction: 0.22407138347625732
# index 1200:       inaccuracy: 0.921%
# -----------------------------------
# target 0.20626031353135313,    prediction: 0.20450633764266968
# index 1300:       inaccuracy: 0.85%
# -----------------------------------
# target 0.21848473261593926,    prediction: 0.21317048370838165
# index 1400:       inaccuracy: 2.432%
# -----------------------------------
# target 0.21932575890507106,    prediction: 0.2188282161951065
# index 1500:       inaccuracy: 0.227%
# -----------------------------------
# target 0.19968647655563543,    prediction: 0.20413947105407715
# index 1600:       inaccuracy: 2.23%
# -----------------------------------
# target 0.17874763147545672,    prediction: 0.18093663454055786
# index 1700:       inaccuracy: 1.225%
# -----------------------------------
# target 0.20078309321821194,    prediction: 0.20209167897701263
# index 1800:       inaccuracy: 0.652%
# -----------------------------------
# target 0.20596928844351525,    prediction: 0.20559558272361755
# index 1900:       inaccuracy: 0.181%
# -----------------------------------
# target 0.2010050756319413,    prediction: 0.20422953367233276
# index 2000:       inaccuracy: 1.604%
# -----------------------------------
# target 0.23217125808286607,    prediction: 0.23438654839992523
# index 2100:       inaccuracy: 0.954%
# -----------------------------------
# target 0.20534751671098972,    prediction: 0.20674799382686615
# index 2200:       inaccuracy: 0.682%
# -----------------------------------
# target 0.20683628089771436,    prediction: 0.20500420033931732
# index 2300:       inaccuracy: 0.886%
# -----------------------------------
# target 0.19928453275405067,    prediction: 0.20002859830856323
# index 2400:       inaccuracy: 0.373%
# -----------------------------------
# target 0.17594531346224904,    prediction: 0.17589136958122253
# index 2500:       inaccuracy: 0.031%
# -----------------------------------
# target 0.1863353458556947,    prediction: 0.17757481336593628
# index 2600:       inaccuracy: 4.701%
# -----------------------------------
# target 0.21966060739194904,    prediction: 0.2192550152540207
# index 2700:       inaccuracy: 0.185%
# -----------------------------------
# target 0.18675643875016343,    prediction: 0.18760064244270325
# index 2800:       inaccuracy: 0.452%
# -----------------------------------
# target 0.19616863499038725,    prediction: 0.19825010001659393
# index 2900:       inaccuracy: 1.061%
# -----------------------------------
# target 0.2251784628549553,    prediction: 0.22392772138118744
# index 3000:       inaccuracy: 0.555%
# -----------------------------------
# target 0.2195906625381558,    prediction: 0.21457169950008392
# index 3100:       inaccuracy: 2.286%
# -----------------------------------
# target 0.20355630648969952,    prediction: 0.2032630443572998
# index 3200:       inaccuracy: 0.144%
# -----------------------------------
# target 0.22631239461802216,    prediction: 0.21963462233543396
# index 3300:       inaccuracy: 2.951%
# -----------------------------------
# target 0.1869886772694548,    prediction: 0.18714481592178345
# index 3400:       inaccuracy: 0.084%
# -----------------------------------
# target 0.20726500155456523,    prediction: 0.20614507794380188
# index 3500:       inaccuracy: 0.54%
# -----------------------------------
# target 0.17584011817046794,    prediction: 0.17192450165748596
# index 3600:       inaccuracy: 2.227%
# -----------------------------------
# target 0.1919179317889565,    prediction: 0.17237600684165955
# index 3700:       inaccuracy: 10.182%
# -----------------------------------
# target 0.21118268215417108,    prediction: 0.21194779872894287
# index 3800:       inaccuracy: 0.362%
# -----------------------------------
# target 0.18248927821881558,    prediction: 0.18829330801963806
# index 3900:       inaccuracy: 3.18%
# -----------------------------------
# target 0.18856663335156235,    prediction: 0.19443096220493317
# index 4000:       inaccuracy: 3.11%
# -----------------------------------
# target 0.18376366810622072,    prediction: 0.18742716312408447
# index 4100:       inaccuracy: 1.994%
# -----------------------------------
# target 0.1714400829811492,    prediction: 0.16681846976280212
# index 4200:       inaccuracy: 2.696%
# -----------------------------------
# target 0.17369138708192564,    prediction: 0.1693890392780304
# index 4300:       inaccuracy: 2.477%
# -----------------------------------
# target 0.1884387072458306,    prediction: 0.1930725872516632
# index 4400:       inaccuracy: 2.459%
# -----------------------------------
# target 0.177239533482222,    prediction: 0.17897582054138184
# index 4500:       inaccuracy: 0.98%
# -----------------------------------
# target 0.22010301336092095,    prediction: 0.21134673058986664
# index 4600:       inaccuracy: 3.978%
# -----------------------------------
# target 0.2228474644261948,    prediction: 0.22786113619804382
# index 4700:       inaccuracy: 2.25%
# -----------------------------------
# target 0.21414956953784212,    prediction: 0.2113710194826126
# index 4800:       inaccuracy: 1.297%
# -----------------------------------
# target 0.20743268472804216,    prediction: 0.20178398489952087
# index 4900:       inaccuracy: 2.723%
# -----------------------------------
# target 0.1707681535624018,    prediction: 0.17304299771785736
# index 5000:       inaccuracy: 1.332%
# -----------------------------------
# target 0.1999919999199992,    prediction: 0.1987181305885315
# index 5100:       inaccuracy: 0.637%
# -----------------------------------
# target 0.20794817672319674,    prediction: 0.2089151293039322
# index 5200:       inaccuracy: 0.465%
# -----------------------------------
# target 0.17093162393162392,    prediction: 0.16572481393814087
# index 5300:       inaccuracy: 3.046%
# -----------------------------------
# target 0.22139196085594412,    prediction: 0.21588996052742004
# index 5400:       inaccuracy: 2.485%
# -----------------------------------
# target 0.18487806681827426,    prediction: 0.18329080939292908
# index 5500:       inaccuracy: 0.859%
# -----------------------------------
# target 0.20610513948862758,    prediction: 0.20637783408164978
# index 5600:       inaccuracy: 0.132%
# -----------------------------------
# target 0.1674916040635495,    prediction: 0.1717173457145691
# index 5700:       inaccuracy: 2.523%
# -----------------------------------
# target 0.1876589316042826,    prediction: 0.17247426509857178
# index 5800:       inaccuracy: 8.092%
# -----------------------------------
# target 0.20544877392313776,    prediction: 0.20102190971374512
# index 5900:       inaccuracy: 2.155%
# -----------------------------------
# target 0.1701637056701382,    prediction: 0.17098650336265564
# index 6000:       inaccuracy: 0.484%
# -----------------------------------
# target 0.19826509368494102,    prediction: 0.19893330335617065
# index 6100:       inaccuracy: 0.337%
# -----------------------------------
# target 0.20755970234450408,    prediction: 0.20749345421791077
# index 6200:       inaccuracy: 0.032%
# -----------------------------------
# target 0.23491478040242914,    prediction: 0.228817880153656
# index 6300:       inaccuracy: 2.595%
# -----------------------------------
# target 0.20972325632609404,    prediction: 0.21069970726966858
# index 6400:       inaccuracy: 0.466%
# -----------------------------------
# target 0.2094772234500529,    prediction: 0.20574650168418884
# index 6500:       inaccuracy: 1.781%
# -----------------------------------
# target 0.24088795740887958,    prediction: 0.24043752253055573
# index 6600:       inaccuracy: 0.187%
# -----------------------------------
# target 0.20456195980156497,    prediction: 0.19979554414749146
# index 6700:       inaccuracy: 2.33%
# -----------------------------------
# target 0.1914164568956441,    prediction: 0.19380336999893188
# index 6800:       inaccuracy: 1.247%
# -----------------------------------
# target 0.2051579282116515,    prediction: 0.20125986635684967
# index 6900:       inaccuracy: 1.9%
# -----------------------------------
# target 0.20224298687377384,    prediction: 0.2007812112569809
# index 7000:       inaccuracy: 0.723%
# -----------------------------------
# target 0.22234698982711656,    prediction: 0.21849285066127777
# index 7100:       inaccuracy: 1.733%
# -----------------------------------
# target 0.16981692819781266,    prediction: 0.16639800369739532
# index 7200:       inaccuracy: 2.013%
# -----------------------------------
# target 0.17894755679632066,    prediction: 0.1771911233663559
# index 7300:       inaccuracy: 0.982%
# -----------------------------------
# target 0.17572887193996803,    prediction: 0.1775358021259308
# index 7400:       inaccuracy: 1.028%
# -----------------------------------
# target 0.21546003016591253,    prediction: 0.21793365478515625
# index 7500:       inaccuracy: 1.148%
# -----------------------------------
# target 0.19814919398785286,    prediction: 0.20004087686538696
# index 7600:       inaccuracy: 0.955%
# -----------------------------------
# target 0.18161756692941988,    prediction: 0.1792328953742981
# index 7700:       inaccuracy: 1.313%
# -----------------------------------
# target 0.18940599310527712,    prediction: 0.19713914394378662
# index 7800:       inaccuracy: 4.083%
# -----------------------------------
# target 0.1825742429636933,    prediction: 0.18654033541679382
# index 7900:       inaccuracy: 2.172%
# -----------------------------------
# target 0.2016150170373208,    prediction: 0.1948399394750595
# index 8000:       inaccuracy: 3.36%
# -----------------------------------
# target 0.18631104320769132,    prediction: 0.18366096913814545
# index 8100:       inaccuracy: 1.422%
# -----------------------------------
# target 0.19100694344956687,    prediction: 0.19630935788154602
# index 8200:       inaccuracy: 2.776%
# -----------------------------------
# target 0.2312103309941385,    prediction: 0.23024088144302368
# index 8300:       inaccuracy: 0.419%
# -----------------------------------
# target 0.18684891575495408,    prediction: 0.1740482598543167
# index 8400:       inaccuracy: 6.851%
# -----------------------------------
# target 0.16822846567967698,    prediction: 0.1705045998096466
# index 8500:       inaccuracy: 1.353%
# -----------------------------------
# target 0.17852105761162587,    prediction: 0.18126598000526428
# index 8600:       inaccuracy: 1.538%
# -----------------------------------
# target 0.16778106831547773,    prediction: 0.1694786697626114
# index 8700:       inaccuracy: 1.012%
# -----------------------------------
# target 0.20252562077206626,    prediction: 0.2040204256772995
# index 8800:       inaccuracy: 0.738%
# -----------------------------------
# target 0.20111827351441589,    prediction: 0.20236358046531677
# index 8900:       inaccuracy: 0.619%
# -----------------------------------
# target 0.16086711711711713,    prediction: 0.1652662754058838
# index 9000:       inaccuracy: 2.735%
# -----------------------------------
# target 0.1796726201171524,    prediction: 0.17404794692993164
# index 9100:       inaccuracy: 3.131%
# -----------------------------------
# target 0.1658429388838212,    prediction: 0.17067039012908936
# index 9200:       inaccuracy: 2.911%
# -----------------------------------
# target 0.1944255410161187,    prediction: 0.19480207562446594
# index 9300:       inaccuracy: 0.194%
# -----------------------------------
# target 0.20602870123314343,    prediction: 0.20947739481925964
# index 9400:       inaccuracy: 1.674%
# -----------------------------------
# target 0.17710925530690141,    prediction: 0.1732206791639328
# index 9500:       inaccuracy: 2.196%
# -----------------------------------
# target 0.16504910456383592,    prediction: 0.17157268524169922
# index 9600:       inaccuracy: 3.953%
# -----------------------------------
# target 0.18914803465365262,    prediction: 0.1784210503101349
# index 9700:       inaccuracy: 5.671%
# -----------------------------------
# target 0.17848282016956715,    prediction: 0.17833849787712097
# index 9800:       inaccuracy: 0.081%
# -----------------------------------
# target 0.2012012314131069,    prediction: 0.20145124197006226
# index 9900:       inaccuracy: 0.124%
# -----------------------------------
# target 0.16841972293570256,    prediction: 0.1681925654411316
# index 10000:       inaccuracy: 0.135%
# -----------------------------------
# target 0.1893593652356695,    prediction: 0.1927257776260376
# index 10100:       inaccuracy: 1.778%
# -----------------------------------
# target 0.18582804471246317,    prediction: 0.18972492218017578
# index 10200:       inaccuracy: 2.097%
# -----------------------------------
# target 0.20141196849759302,    prediction: 0.19776156544685364
# index 10300:       inaccuracy: 1.812%
# -----------------------------------
# target 0.20711903726257794,    prediction: 0.20356465876102448
# index 10400:       inaccuracy: 1.716%
# -----------------------------------
# target 0.17221217600964436,    prediction: 0.17267851531505585
# index 10500:       inaccuracy: 0.271%
# -----------------------------------
# target 0.15724091298639012,    prediction: 0.16284343600273132
# index 10600:       inaccuracy: 3.563%
# -----------------------------------
# target 0.1557505996697922,    prediction: 0.16308143734931946
# index 10700:       inaccuracy: 4.707%
# -----------------------------------
# target 0.2032687245266143,    prediction: 0.19974850118160248
# index 10800:       inaccuracy: 1.732%
# -----------------------------------
# target 0.2057065860256529,    prediction: 0.19967079162597656
# index 10900:       inaccuracy: 2.934%
# -----------------------------------
# target 0.1901027556772274,    prediction: 0.19144880771636963
# index 11000:       inaccuracy: 0.708%
# -----------------------------------
# target 0.15675408756721168,    prediction: 0.16399458050727844
# index 11100:       inaccuracy: 4.619%
# -----------------------------------
# target 0.220856524427953,    prediction: 0.2186109572649002
# index 11200:       inaccuracy: 1.017%
# -----------------------------------
# target 0.20371181485744552,    prediction: 0.19831368327140808
# index 11300:       inaccuracy: 2.65%
# -----------------------------------
# target 0.20732731362934242,    prediction: 0.20466172695159912
# index 11400:       inaccuracy: 1.286%
# -----------------------------------
# target 0.19425180177555024,    prediction: 0.19195103645324707
# index 11500:       inaccuracy: 1.184%
# -----------------------------------
# target 0.19513504019982827,    prediction: 0.19431012868881226
# index 11600:       inaccuracy: 0.423%
# -----------------------------------
# target 0.2187452147091637,    prediction: 0.21224632859230042
# index 11700:       inaccuracy: 2.971%
# -----------------------------------
# target 0.1586705913155243,    prediction: 0.16390344500541687
# index 11800:       inaccuracy: 3.298%
# -----------------------------------
# target 0.19203034231120072,    prediction: 0.1806429773569107
# index 11900:       inaccuracy: 5.93%
# -----------------------------------
# target 0.17512719248316505,    prediction: 0.17061267793178558
# index 12000:       inaccuracy: 2.578%
# -----------------------------------
# target 0.1747461684986806,    prediction: 0.17283222079277039
# index 12100:       inaccuracy: 1.095%
# -----------------------------------
# target 0.205419230255657,    prediction: 0.20501944422721863
# index 12200:       inaccuracy: 0.195%
# -----------------------------------
# target 0.19543251377868115,    prediction: 0.19754324853420258
# index 12300:       inaccuracy: 1.08%
# -----------------------------------
# target 0.17933749417124,    prediction: 0.17722579836845398
# index 12400:       inaccuracy: 1.177%
# -----------------------------------
# target 0.19253504313000616,    prediction: 0.19784140586853027
# index 12500:       inaccuracy: 2.756%
# -----------------------------------
# target 0.18455731714069507,    prediction: 0.18847082555294037
# index 12600:       inaccuracy: 2.12%
# -----------------------------------
# target 0.1683346660494087,    prediction: 0.17096982896327972
# index 12700:       inaccuracy: 1.565%
# -----------------------------------
# target 0.16333714472394642,    prediction: 0.16802668571472168
# index 12800:       inaccuracy: 2.871%
# -----------------------------------
# target 0.1845283680417793,    prediction: 0.19057902693748474
# index 12900:       inaccuracy: 3.279%
# -----------------------------------
# target 0.16387518641734541,    prediction: 0.16837924718856812
# index 13000:       inaccuracy: 2.748%
# -----------------------------------
# target 0.2251201638956741,    prediction: 0.22142085433006287
# index 13100:       inaccuracy: 1.643%
# -----------------------------------
# target 0.19589194060259374,    prediction: 0.19817444682121277
# index 13200:       inaccuracy: 1.165%
# -----------------------------------
# target 0.1905356224157314,    prediction: 0.19417476654052734
# index 13300:       inaccuracy: 1.91%
# -----------------------------------
# target 0.15093584905660376,    prediction: 0.15726663172245026
# index 13400:       inaccuracy: 4.194%
# -----------------------------------
# target 0.1723799098407992,    prediction: 0.16939902305603027
# index 13500:       inaccuracy: 1.729%
# -----------------------------------
# target 0.16865834015028208,    prediction: 0.16534888744354248
# index 13600:       inaccuracy: 1.962%
# -----------------------------------
# target 0.17865023002367234,    prediction: 0.17835882306098938
# index 13700:       inaccuracy: 0.163%
# -----------------------------------
# target 0.1904376475965567,    prediction: 0.18943148851394653
# index 13800:       inaccuracy: 0.528%
# -----------------------------------
# target 0.16985875538266845,    prediction: 0.16219912469387054
# index 13900:       inaccuracy: 4.509%
# -----------------------------------
# target 0.1898212743339313,    prediction: 0.18908990919589996
# index 14000:       inaccuracy: 0.385%
# -----------------------------------
# target 0.18252758586070622,    prediction: 0.18005378544330597
# index 14100:       inaccuracy: 1.355%
# -----------------------------------
# target 0.17902444701058984,    prediction: 0.17432460188865662
# index 14200:       inaccuracy: 2.625%
# -----------------------------------
# target 0.20150938073070954,    prediction: 0.2037762701511383
# index 14300:       inaccuracy: 1.125%
# -----------------------------------
# target 0.1677036863113407,    prediction: 0.16308143734931946
# index 14400:       inaccuracy: 2.756%
# -----------------------------------
# target 0.17039858221290663,    prediction: 0.17049777507781982
# index 14500:       inaccuracy: 0.058%
# -----------------------------------
# target 0.2257070627271291,    prediction: 0.22447022795677185
# index 14600:       inaccuracy: 0.548%
# -----------------------------------
# target 0.18001386176044357,    prediction: 0.18160730600357056
# index 14700:       inaccuracy: 0.885%
# -----------------------------------
# target 0.2083836952444463,    prediction: 0.20589317381381989
# index 14800:       inaccuracy: 1.195%
# -----------------------------------
# target 0.18326017832106956,    prediction: 0.183496356010437
# index 14900:       inaccuracy: 0.129%
# -----------------------------------
# target 0.19032890479272147,    prediction: 0.19594717025756836
# index 15000:       inaccuracy: 2.952%
# -----------------------------------
# target 0.20066221843174634,    prediction: 0.19667832553386688
# index 15100:       inaccuracy: 1.985%
# -----------------------------------
# target 0.15304029752521464,    prediction: 0.16324648261070251
# index 15200:       inaccuracy: 6.669%
# -----------------------------------
# target 0.18008031983863995,    prediction: 0.1745425909757614
# index 15300:       inaccuracy: 3.075%
# -----------------------------------
# target 0.19096499436625097,    prediction: 0.19698001444339752
# index 15400:       inaccuracy: 3.15%
# -----------------------------------
# target 0.20558816575346692,    prediction: 0.2028617113828659
# index 15500:       inaccuracy: 1.326%
# -----------------------------------
# target 0.17827598502406847,    prediction: 0.17840848863124847
# index 15600:       inaccuracy: 0.074%
# -----------------------------------
# target 0.15179391427769048,    prediction: 0.16092705726623535
# index 15700:       inaccuracy: 6.017%
# -----------------------------------
# target 0.18210210975842947,    prediction: 0.18727156519889832
# index 15800:       inaccuracy: 2.839%
# -----------------------------------
# target 0.2277064261966571,    prediction: 0.2301061600446701
# index 15900:       inaccuracy: 1.054%
# -----------------------------------
# target 0.18590059398209688,    prediction: 0.19267377257347107
# index 16000:       inaccuracy: 3.643%
# -----------------------------------
# target 0.1499512634025643,    prediction: 0.16326557099819183
# index 16100:       inaccuracy: 8.879%
# -----------------------------------
# target 0.18044916041830206,    prediction: 0.17776069045066833
# index 16200:       inaccuracy: 1.49%
# -----------------------------------
# target 0.19424048174048175,    prediction: 0.19572383165359497
# index 16300:       inaccuracy: 0.764%
# -----------------------------------
# target 0.21946776406035665,    prediction: 0.2209833860397339
# index 16400:       inaccuracy: 0.691%
# -----------------------------------
# target 0.20302316610155727,    prediction: 0.2033243030309677
# index 16500:       inaccuracy: 0.148%
# -----------------------------------
# target 0.18043939188884378,    prediction: 0.18093392252922058
# index 16600:       inaccuracy: 0.274%
# -----------------------------------
# target 0.20754031672235942,    prediction: 0.21216031908988953
# index 16700:       inaccuracy: 2.226%
# -----------------------------------
# target 0.16359501664662526,    prediction: 0.16928285360336304
# index 16800:       inaccuracy: 3.477%
# -----------------------------------
# target 0.20378861987445993,    prediction: 0.1981886774301529
# index 16900:       inaccuracy: 2.748%
# -----------------------------------
# target 0.1848455999926058,    prediction: 0.19076687097549438
# index 17000:       inaccuracy: 3.203%
# -----------------------------------
# target 0.21043383103422877,    prediction: 0.21019501984119415
# index 17100:       inaccuracy: 0.113%
# -----------------------------------
# target 0.2009303540569867,    prediction: 0.20078343152999878
# index 17200:       inaccuracy: 0.073%
# -----------------------------------
# target 0.15536944817781367,    prediction: 0.16475188732147217
# index 17300:       inaccuracy: 6.039%
# -----------------------------------
# target 0.20646047116635352,    prediction: 0.20860938727855682
# index 17400:       inaccuracy: 1.041%
# -----------------------------------
# target 0.2027823124423309,    prediction: 0.19919845461845398
# index 17500:       inaccuracy: 1.767%
# -----------------------------------
# target 0.16419675038382908,    prediction: 0.16779032349586487
# index 17600:       inaccuracy: 2.189%
# -----------------------------------
# target 0.181283369138589,    prediction: 0.17253196239471436
# index 17700:       inaccuracy: 4.827%
# -----------------------------------
# target 0.1524465076570087,    prediction: 0.16215083003044128
# index 17800:       inaccuracy: 6.366%
# -----------------------------------
# target 0.1441213562497748,    prediction: 0.15653139352798462
# index 17900:       inaccuracy: 8.611%
# -----------------------------------
# target 0.17108808910713216,    prediction: 0.16982287168502808
# index 18000:       inaccuracy: 0.74%
# -----------------------------------
# target 0.20140791169835642,    prediction: 0.1968010812997818
# index 18100:       inaccuracy: 2.287%
# -----------------------------------
# target 0.21135229962800134,    prediction: 0.20851406455039978
# index 18200:       inaccuracy: 1.343%
# -----------------------------------
# target 0.21160947634616808,    prediction: 0.21115797758102417
# index 18300:       inaccuracy: 0.213%
# -----------------------------------
# target 0.1662897244441488,    prediction: 0.164903461933136
# index 18400:       inaccuracy: 0.834%
# -----------------------------------
# target 0.19359366529853636,    prediction: 0.19029738008975983
# index 18500:       inaccuracy: 1.703%
# -----------------------------------
# target 0.16277877258668402,    prediction: 0.16499361395835876
# index 18600:       inaccuracy: 1.361%
# -----------------------------------
# target 0.18966465612078448,    prediction: 0.18858100473880768
# index 18700:       inaccuracy: 0.571%
# -----------------------------------
# target 0.122488102748158,    prediction: 0.15640059113502502
# index 18800:       inaccuracy: 27.686%
# -----------------------------------
# target 0.1994992318895517,    prediction: 0.19660408794879913
# index 18900:       inaccuracy: 1.451%
# -----------------------------------
# target 0.1970286592514507,    prediction: 0.19754835963249207
# index 19000:       inaccuracy: 0.264%
# -----------------------------------
# target 0.18673202614379086,    prediction: 0.19449776411056519
# index 19100:       inaccuracy: 4.159%
# -----------------------------------
# target 0.19788059287990026,    prediction: 0.19889739155769348
# index 19200:       inaccuracy: 0.514%
# -----------------------------------
# target 0.20439052806933272,    prediction: 0.2027968466281891
# index 19300:       inaccuracy: 0.78%
# -----------------------------------
# target 0.14638520264384894,    prediction: 0.15570561587810516
# index 19400:       inaccuracy: 6.367%
# -----------------------------------
# target 0.20240878498051718,    prediction: 0.19850081205368042
# index 19500:       inaccuracy: 1.931%
# -----------------------------------
# target 0.19640945562397494,    prediction: 0.1942727118730545
# index 19600:       inaccuracy: 1.088%
# -----------------------------------
# target 0.18889969868991507,    prediction: 0.1921750009059906
# index 19700:       inaccuracy: 1.734%
# -----------------------------------
# target 0.19024742915307122,    prediction: 0.1884223073720932
# index 19800:       inaccuracy: 0.959%
# -----------------------------------
# target 0.1819232063749079,    prediction: 0.18928183615207672
# index 19900:       inaccuracy: 4.045%
# -----------------------------------
# Average inaccuracy on the second graph:  2.053
