# %% [markdown]
# # The feedforward neural network model for learning PageRank

# %%
import time
from dihelpers import *

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

# %% [markdown]
# ## Loading the dataset from numpy files

# %%
# Pageank as the target or label data
target_pagerank = np.load("epinions_pageranks.npy", mmap_mode=None, allow_pickle=False, fix_imports=True, encoding='ASCII')
target_pagerank[0]
# Out:
# array([0.00082304])

# %%
# scaling the PageRank data
target_pagerank = target_pagerank * 10000
target_pagerank[0:10]
# Out:
# array([[ 8.23038636],
#        [10.63970906],
#        [ 3.04659061],
#        [ 0.60241765],
#        [ 2.1125303 ],
#        [ 2.98758742],
#        [ 3.50898413],
#        [ 0.48461399],
#        [ 1.68108362],
#        [ 0.23305616]])

# %%
target_pagerank.shape
# Out:
# (75879, 1)

# %%
# the order 5 NFDC matrix as the feature set
matrix_1 = np.load("discounted_epinions_NDFC_matrix_r1_15_sta1_max70_rad3_inward.npy", mmap_mode=None, allow_pickle=False, fix_imports=True, encoding='ASCII')

# %%
matrix_1.shape
# Out:
# (75879, 4, 43)

# %%
matrix_1 = matrix_1.reshape(matrix_1.shape[0],-1)
matrix_1.shape
# Out:
# (75879, 172)

# %% [markdown]
# # Converting the data into pytorch tenors

# %%
features = torch.from_numpy(matrix_1)
targets = torch.from_numpy(target_pagerank)
features.shape, targets.shape
# Out:
# (torch.Size([75879, 172]), torch.Size([75879, 1]))

# %%
# Activating the automatic gradient 
features.requires_grad_(True)
targets.requires_grad_(True)
# Out:
# tensor([[ 8.2304],
#         [10.6397],
#         [ 3.0466],
#         ...,
#         [ 0.0287],
#         [ 0.0287],
#         [ 0.0287]], dtype=torch.float64, requires_grad=True)

# %%
# Shuffling and dividing the indecies
n_samples = features.shape[0]
n_test = 55879
shuffled_ind = torch.randperm(n_samples)
train_ind = shuffled_ind[:-n_test]
test_ind = shuffled_ind[-n_test:]
# Dividing features and targets into tain and test sets
train_features = features[train_ind]
test_features = features[test_ind]
train_targets = targets[train_ind]
test_targets = targets[test_ind]
train_features.shape, test_features.shape, train_targets.shape, test_targets.shape
# Out:
# (torch.Size([20000, 172]),
#  torch.Size([55879, 172]),
#  torch.Size([20000, 1]),
#  torch.Size([55879, 1]))

# %% [markdown]
# ## A function for dividing train data into batches

# %%
# dividing train_features and train_targets into batches
def next_batch(train_features, train_targets, batch_size=100):
    num_features = train_features.shape[0]
    # Shuffling
    shuffled_ind = torch.randperm(num_features)
    shuffled_train_features = train_features[shuffled_ind]
    shuffled_train_targets = train_targets[shuffled_ind]
    # Dividing
    i = 0
    while i < num_features:
        i += batch_size
        yield (shuffled_train_features[i-batch_size:i], shuffled_train_targets[i-batch_size:i])
    return

# %% [markdown]
# ## The feedforward neural network model

# %%
# The Feedforward Neural Network 
class FFNN_model(nn.Module):
    def __init__(self):
        super().__init__()
        num_features = features.shape[1]
        self.fc1 = nn.Linear(num_features, 400)
        self.fc2 = nn.Linear(400, 800)
        self.fc3 = nn.Linear(800, 200)
        self.fc4 = nn.Linear(200, 64)
        self.fc5 = nn.Linear(64, 8)
        self.fc6 = nn.Linear(8, 1)
        self.dropout1 = nn.Dropout(0.4)
        self.dropout2 = nn.Dropout(0.3)
        self.dropout3 = nn.Dropout(0.5)
    
    def forward(self, X):
        X = torch.tanh(self.fc1(X))
        X = torch.relu(self.fc2(X))
        X = self.dropout1(X)
        X = torch.relu(self.fc3(X))
        X = self.dropout3(X)
        X = torch.relu(self.fc4(X))
        X = self.dropout2(X)
        X = torch.tanh(self.fc5(X))
        return self.fc6(X)

# %%
# Instantiation of the model
torch.manual_seed(42)
model = FFNN_model()
model
# Out:
# FFNN_model(
#   (fc1): Linear(in_features=172, out_features=400, bias=True)
#   (fc2): Linear(in_features=400, out_features=800, bias=True)
#   (fc3): Linear(in_features=800, out_features=200, bias=True)
#   (fc4): Linear(in_features=200, out_features=64, bias=True)
#   (fc5): Linear(in_features=64, out_features=8, bias=True)
#   (fc6): Linear(in_features=8, out_features=1, bias=True)
#   (dropout1): Dropout(p=0.4, inplace=False)
#   (dropout2): Dropout(p=0.3, inplace=False)
#   (dropout3): Dropout(p=0.5, inplace=False)
# )

# %%
# Number of parameters
num_para = 0
for param in model.parameters():
    print(param.numel())
    num_para += param.numel()
print("----------------------")
print(f'Number of all parameters: \n{num_para}')
# Out:
# 68800
# 400
# 320000
# 800
# 160000
# 200
# 12800
# 64
# 512
# 8
# 8
# 1
# ----------------------
# Number of all parameters:
# 563593

# %%
# Objective function and optimmizer
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=1e-3)
# optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

# %% [markdown]
# ## Defining the Training Loop

# %%
def training_loop(n_epochs=1000,
                  batch_size=100,
                  optimizer=optimizer, 
                  model=model, 
                  loss_fn=criterion, 
                  train_features=train_features, 
                  test_features=test_features, 
                  train_targets=train_targets, 
                  test_targets=test_targets):
    num_features = train_features.shape[0]
    start_time = time.time()
    all_train_loss, all_test_loss = np.zeros(n_epochs), np.zeros(n_epochs)
    for epoch in range(1, n_epochs +1):
        # Training: 
        epoch_losses = []
        # looping through batches
        for train_features, train_targets in next_batch(train_features=train_features, 
                                                        train_targets=train_targets, batch_size=batch_size): 
            train_preds = model(train_features.float())
            train_loss = loss_fn(train_targets.float(), train_preds.float())
            optimizer.zero_grad()
            train_loss.backward(retain_graph=True)
            optimizer.step()
            
            epoch_losses.append(train_loss.item())
        average_epoch_loss = sum(epoch_losses)/len(epoch_losses)
        
        # Test:
        with torch.no_grad():
            test_preds = model(test_features.float())
            test_loss = loss_fn(test_targets.float(), test_preds.float())
        
        all_train_loss[epoch - 1] = average_epoch_loss
        all_test_loss[epoch - 1] = test_loss.item()
        # Printing the result: 
        if (epoch < 100 and epoch % 10 == 0) or epoch % 100 == 0:
            print(f"EPOCH: {epoch:{7}}")
            print(f"MEAN TRAIN LOSS:   {average_epoch_loss:.11f},    TEST LOSS:   {test_loss.item():.11f}")
            print("-----------------------------------------")
    print("The total time = ", np.round(time.time() - start_time, 3), " seconds!")
    return all_train_loss, all_test_loss

# %% [markdown]
# # Training the model

# %%
losses = training_loop(n_epochs=1000,
                  batch_size=400,
                  optimizer=optimizer, 
                  model=model, 
                  loss_fn=criterion, 
                  train_features=train_features, 
                  test_features=test_features, 
                  train_targets=train_targets, 
                  test_targets=test_targets)
# Out:
# EPOCH:      10
# MEAN TRAIN LOSS:   0.20808953047,    TEST LOSS:   0.17618757486
# -----------------------------------------
# EPOCH:      20
# MEAN TRAIN LOSS:   0.20346432924,    TEST LOSS:   0.17273277044
# -----------------------------------------
# EPOCH:      30
# MEAN TRAIN LOSS:   0.19331371784,    TEST LOSS:   0.16960695386
# -----------------------------------------
# EPOCH:      40
# MEAN TRAIN LOSS:   0.18650512397,    TEST LOSS:   0.16623705626
# -----------------------------------------
# EPOCH:      50
# MEAN TRAIN LOSS:   0.18016521633,    TEST LOSS:   0.16121105850
# -----------------------------------------
# EPOCH:      60
# MEAN TRAIN LOSS:   0.17371949553,    TEST LOSS:   0.16276387870
# -----------------------------------------
# EPOCH:      70
# MEAN TRAIN LOSS:   0.16747727990,    TEST LOSS:   0.15677383542
# -----------------------------------------
# EPOCH:      80
# MEAN TRAIN LOSS:   0.16429983079,    TEST LOSS:   0.15423041582
# -----------------------------------------
# EPOCH:      90
# MEAN TRAIN LOSS:   0.15970069170,    TEST LOSS:   0.15323615074
# -----------------------------------------
# EPOCH:     100
# MEAN TRAIN LOSS:   0.15540584922,    TEST LOSS:   0.15178352594
# -----------------------------------------
# EPOCH:     200
# MEAN TRAIN LOSS:   0.11482477188,    TEST LOSS:   0.13175494969
# -----------------------------------------
# EPOCH:     300
# MEAN TRAIN LOSS:   0.08856750280,    TEST LOSS:   0.12941658497
# -----------------------------------------
# EPOCH:     400
# MEAN TRAIN LOSS:   0.07129392773,    TEST LOSS:   0.12819628417
# -----------------------------------------
# EPOCH:     500
# MEAN TRAIN LOSS:   0.06134371459,    TEST LOSS:   0.15964397788
# -----------------------------------------
# EPOCH:     600
# MEAN TRAIN LOSS:   0.05463747680,    TEST LOSS:   0.13929674029
# -----------------------------------------
# EPOCH:     700
# MEAN TRAIN LOSS:   0.05074848235,    TEST LOSS:   0.16680599749
# -----------------------------------------
# EPOCH:     800
# MEAN TRAIN LOSS:   0.04897792637,    TEST LOSS:   0.20777465403
# -----------------------------------------
# EPOCH:     900
# MEAN TRAIN LOSS:   0.05026488379,    TEST LOSS:   0.28292098641
# -----------------------------------------
# EPOCH:    1000
# MEAN TRAIN LOSS:   0.02985734493,    TEST LOSS:   0.17490120232
# -----------------------------------------
# The total time =  1456.836  seconds!

# %%
model.eval()
errors = []
for i in range(n_test):
    targ = test_targets[i].item()
    feat = test_features[i].float().view(1,1,features.shape[1])
    pred = model(feat).item()
    inaccuracy = abs(1 - pred/targ) * 100
    errors.append(inaccuracy)
    if i%100 == 0:
        print(f"target {targ},    prediction: {pred}\nindex {i}:       inaccuracy: {np.round(inaccuracy, 3)}%")
        print("-----------------------------------------------------------------")
# Out:
# target 0.14155744456624883,    prediction: 0.30246633291244507
# index 0:       inaccuracy: 113.67%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 100:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.03571832180941778,    prediction: 0.03784945607185364
# index 200:       inaccuracy: 5.967%
# -----------------------------------------------------------------
# target 0.03600122962909758,    prediction: 0.03369048237800598
# index 300:       inaccuracy: 6.419%
# -----------------------------------------------------------------
# target 0.02939993686653839,    prediction: 0.029312223196029663
# index 400:       inaccuracy: 0.298%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 500:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.03135021802903377,    prediction: 0.03087770938873291
# index 600:       inaccuracy: 1.507%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 700:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.04935585569468517,    prediction: 0.04048439860343933
# index 800:       inaccuracy: 17.974%
# -----------------------------------------------------------------
# target 0.06441514466681349,    prediction: 0.07019266486167908
# index 900:       inaccuracy: 8.969%
# -----------------------------------------------------------------
# target 0.18347862536596166,    prediction: 0.4523693919181824
# index 1000:       inaccuracy: 146.552%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 1100:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.029960899751481657,    prediction: 0.02954697608947754
# index 1200:       inaccuracy: 1.382%
# -----------------------------------------------------------------
# target 0.06658918214801333,    prediction: 0.06599965691566467
# index 1300:       inaccuracy: 0.885%
# -----------------------------------------------------------------
# target 0.041235908028424945,    prediction: 0.0468592643737793
# index 1400:       inaccuracy: 13.637%
# -----------------------------------------------------------------
# target 1.0761485198678724,    prediction: 0.4850294589996338
# index 1500:       inaccuracy: 54.929%
# -----------------------------------------------------------------
# target 1.416833774338438,    prediction: 0.47133851051330566
# index 1600:       inaccuracy: 66.733%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 1700:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.06350600326633249,    prediction: 0.05376923084259033
# index 1800:       inaccuracy: 15.332%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 1900:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 1.8705003217267366,    prediction: 4.6483354568481445
# index 2000:       inaccuracy: 148.508%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 2100:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.6216842283353851,    prediction: 0.3751857578754425
# index 2200:       inaccuracy: 39.65%
# -----------------------------------------------------------------
# target 1.3355338671094783,    prediction: 0.37521547079086304
# index 2300:       inaccuracy: 71.905%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 2400:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 2500:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.09239282003815469,    prediction: 0.10086366534233093
# index 2600:       inaccuracy: 9.168%
# -----------------------------------------------------------------
# target 0.05629390979637471,    prediction: 0.03522107005119324
# index 2700:       inaccuracy: 37.434%
# -----------------------------------------------------------------
# target 0.05886563218084624,    prediction: 0.06019565463066101
# index 2800:       inaccuracy: 2.259%
# -----------------------------------------------------------------
# target 0.05480195853221995,    prediction: 0.055958956480026245
# index 2900:       inaccuracy: 2.111%
# -----------------------------------------------------------------
# target 0.05656336741117635,    prediction: 0.03792491555213928
# index 3000:       inaccuracy: 32.951%
# -----------------------------------------------------------------
# target 0.036549736894814895,    prediction: 0.03217124938964844
# index 3100:       inaccuracy: 11.98%
# -----------------------------------------------------------------
# target 0.09370946781138433,    prediction: 0.14274391531944275
# index 3200:       inaccuracy: 52.326%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 3300:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 3400:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 3500:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.046163341172730674,    prediction: 0.052071452140808105
# index 3600:       inaccuracy: 12.798%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 3700:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 3800:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 3900:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.09072327791089964,    prediction: 0.06788113713264465
# index 4000:       inaccuracy: 25.178%
# -----------------------------------------------------------------
# target 0.1388299805087226,    prediction: 0.06434783339500427
# index 4100:       inaccuracy: 53.65%
# -----------------------------------------------------------------
# target 0.07079163142881056,    prediction: 0.08844247460365295
# index 4200:       inaccuracy: 24.934%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 4300:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.03399902328316266,    prediction: 0.03049328923225403
# index 4400:       inaccuracy: 10.311%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 4500:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.24971440084672078,    prediction: 0.1653819978237152
# index 4600:       inaccuracy: 33.772%
# -----------------------------------------------------------------
# target 3.4501810448230237,    prediction: 6.731948375701904
# index 4700:       inaccuracy: 95.119%
# -----------------------------------------------------------------
# target 0.05482844800647255,    prediction: 0.07849794626235962
# index 4800:       inaccuracy: 43.17%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 4900:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.46428138558363014,    prediction: 0.824120283126831
# index 5000:       inaccuracy: 77.504%
# -----------------------------------------------------------------
# target 0.03934834588909972,    prediction: 0.04096728563308716
# index 5100:       inaccuracy: 4.114%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 5200:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 5300:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 5400:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 5500:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 5600:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 5700:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 5800:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 5900:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.09278652817572393,    prediction: 0.059301555156707764
# index 6000:       inaccuracy: 36.088%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 6100:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 6200:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 6300:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.04136519406915699,    prediction: 0.034589529037475586
# index 6400:       inaccuracy: 16.38%
# -----------------------------------------------------------------
# target 0.455797593902766,    prediction: 0.3270280659198761
# index 6500:       inaccuracy: 28.251%
# -----------------------------------------------------------------
# target 0.13767532183123019,    prediction: 0.2825239300727844
# index 6600:       inaccuracy: 105.21%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 6700:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.0320756082625224,    prediction: 0.030729591846466064
# index 6800:       inaccuracy: 4.196%
# -----------------------------------------------------------------
# target 0.04631680192392699,    prediction: 0.05153664946556091
# index 6900:       inaccuracy: 11.27%
# -----------------------------------------------------------------
# target 0.14221630142276062,    prediction: 0.09068113565444946
# index 7000:       inaccuracy: 36.237%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 7100:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.03279264296835121,    prediction: 0.030565530061721802
# index 7200:       inaccuracy: 6.792%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 7300:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.20985611145013486,    prediction: 0.19897869229316711
# index 7400:       inaccuracy: 5.183%
# -----------------------------------------------------------------
# target 0.07918515010172246,    prediction: 0.04259297251701355
# index 7500:       inaccuracy: 46.211%
# -----------------------------------------------------------------
# target 0.06758613888516901,    prediction: 0.06551927328109741
# index 7600:       inaccuracy: 3.058%
# -----------------------------------------------------------------
# target 0.04016140453469801,    prediction: 0.038490861654281616
# index 7700:       inaccuracy: 4.16%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 7800:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.0559243240970024,    prediction: 0.07474276423454285
# index 7900:       inaccuracy: 33.65%
# -----------------------------------------------------------------
# target 0.042909636879458216,    prediction: 0.036159396171569824
# index 8000:       inaccuracy: 15.731%
# -----------------------------------------------------------------
# target 0.03154719721921892,    prediction: 0.03062322735786438
# index 8100:       inaccuracy: 2.929%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 8200:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.030871442026172403,    prediction: 0.03030461072921753
# index 8300:       inaccuracy: 1.836%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 8400:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.04482406856130297,    prediction: 0.039417415857315063
# index 8500:       inaccuracy: 12.062%
# -----------------------------------------------------------------
# target 0.03590389193184512,    prediction: 0.03941050171852112
# index 8600:       inaccuracy: 9.767%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 8700:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.041872967474122016,    prediction: 0.036474406719207764
# index 8800:       inaccuracy: 12.893%
# -----------------------------------------------------------------
# target 0.13664707605382082,    prediction: 0.13005593419075012
# index 8900:       inaccuracy: 4.823%
# -----------------------------------------------------------------
# target 0.061060800522169084,    prediction: 0.05388420820236206
# index 9000:       inaccuracy: 11.753%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 9100:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.04459180998493924,    prediction: 0.03525921702384949
# index 9200:       inaccuracy: 20.929%
# -----------------------------------------------------------------
# target 0.05313212396829685,    prediction: 0.05740472674369812
# index 9300:       inaccuracy: 8.041%
# -----------------------------------------------------------------
# target 0.16815840180413186,    prediction: 0.480970561504364
# index 9400:       inaccuracy: 186.022%
# -----------------------------------------------------------------
# target 0.10210178767067869,    prediction: 0.06947788596153259
# index 9500:       inaccuracy: 31.952%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 9600:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 9700:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.0769629067618737,    prediction: 0.0762559175491333
# index 9800:       inaccuracy: 0.919%
# -----------------------------------------------------------------
# target 0.13879075246717734,    prediction: 0.13898494839668274
# index 9900:       inaccuracy: 0.14%
# -----------------------------------------------------------------
# target 0.04473281731456172,    prediction: 0.03518757224082947
# index 10000:       inaccuracy: 21.338%
# -----------------------------------------------------------------
# target 0.1922520136668707,    prediction: 0.10595184564590454
# index 10100:       inaccuracy: 44.889%
# -----------------------------------------------------------------
# target 0.045250910592173496,    prediction: 0.05939227342605591
# index 10200:       inaccuracy: 31.251%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 10300:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.03129621349408912,    prediction: 0.02984556555747986
# index 10400:       inaccuracy: 4.635%
# -----------------------------------------------------------------
# target 0.18561664424864724,    prediction: 0.2813045382499695
# index 10500:       inaccuracy: 51.551%
# -----------------------------------------------------------------
# target 0.03308864912013943,    prediction: 0.031381815671920776
# index 10600:       inaccuracy: 5.158%
# -----------------------------------------------------------------
# target 0.06014459040325145,    prediction: 0.04412683844566345
# index 10700:       inaccuracy: 26.632%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 10800:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 10900:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 11000:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 11100:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 11200:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.04331922747418329,    prediction: 0.046148210763931274
# index 11300:       inaccuracy: 6.531%
# -----------------------------------------------------------------
# target 0.08461793076919565,    prediction: 0.08667272329330444
# index 11400:       inaccuracy: 2.428%
# -----------------------------------------------------------------
# target 0.036729168390948294,    prediction: 0.033797234296798706
# index 11500:       inaccuracy: 7.983%
# -----------------------------------------------------------------
# target 1.4203758966881428,    prediction: 1.2390482425689697
# index 11600:       inaccuracy: 12.766%
# -----------------------------------------------------------------
# target 0.06165462904404695,    prediction: 0.07654416561126709
# index 11700:       inaccuracy: 24.15%
# -----------------------------------------------------------------
# target 0.06054464935304737,    prediction: 0.13511916995048523
# index 11800:       inaccuracy: 123.173%
# -----------------------------------------------------------------
# target 0.06912956894294135,    prediction: 0.11531659960746765
# index 11900:       inaccuracy: 66.812%
# -----------------------------------------------------------------
# target 0.03589996810065836,    prediction: 0.03111019730567932
# index 12000:       inaccuracy: 13.342%
# -----------------------------------------------------------------
# target 0.20810016600577896,    prediction: 0.15564602613449097
# index 12100:       inaccuracy: 25.206%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 12200:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.08177054188823364,    prediction: 0.05869296193122864
# index 12300:       inaccuracy: 28.222%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 12400:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.15604778510673611,    prediction: 0.115876704454422
# index 12500:       inaccuracy: 25.743%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 12600:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.03199699662101514,    prediction: 0.03558799624443054
# index 12700:       inaccuracy: 11.223%
# -----------------------------------------------------------------
# target 0.07752436732352908,    prediction: 0.08298638463020325
# index 12800:       inaccuracy: 7.046%
# -----------------------------------------------------------------
# target 0.04147800149232172,    prediction: 0.04156389832496643
# index 12900:       inaccuracy: 0.207%
# -----------------------------------------------------------------
# target 0.03257471762683728,    prediction: 0.03302916884422302
# index 13000:       inaccuracy: 1.395%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 13100:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.06813188160416213,    prediction: 0.05477249622344971
# index 13200:       inaccuracy: 19.608%
# -----------------------------------------------------------------
# target 0.08927384572997472,    prediction: 0.1665755808353424
# index 13300:       inaccuracy: 86.589%
# -----------------------------------------------------------------
# target 0.07368141395544596,    prediction: 0.061870038509368896
# index 13400:       inaccuracy: 16.03%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 13500:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 13600:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.04636205486744591,    prediction: 0.04305437207221985
# index 13700:       inaccuracy: 7.134%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 13800:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 13900:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 14000:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 14100:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.08278356492811746,    prediction: 0.07233628630638123
# index 14200:       inaccuracy: 12.62%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 14300:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.05407642795425815,    prediction: 0.034589529037475586
# index 14400:       inaccuracy: 36.036%
# -----------------------------------------------------------------
# target 0.0812678191884137,    prediction: 0.10528174042701721
# index 14500:       inaccuracy: 29.549%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 14600:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 14700:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 14800:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.030121685554773122,    prediction: 0.03032010793685913
# index 14900:       inaccuracy: 0.659%
# -----------------------------------------------------------------
# target 0.9861118370965423,    prediction: 0.22846120595932007
# index 15000:       inaccuracy: 76.832%
# -----------------------------------------------------------------
# target 0.03707776599252929,    prediction: 0.03331625461578369
# index 15100:       inaccuracy: 10.145%
# -----------------------------------------------------------------
# target 0.3921405575591184,    prediction: 0.3585558533668518
# index 15200:       inaccuracy: 8.564%
# -----------------------------------------------------------------
# target 0.042117647647319074,    prediction: 0.03632351756095886
# index 15300:       inaccuracy: 13.757%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 15400:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.041551870473684915,    prediction: 0.03583678603172302
# index 15500:       inaccuracy: 13.754%
# -----------------------------------------------------------------
# target 0.050726282758528814,    prediction: 0.04270792007446289
# index 15600:       inaccuracy: 15.807%
# -----------------------------------------------------------------
# target 0.06981603743802307,    prediction: 0.041735172271728516
# index 15700:       inaccuracy: 40.221%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 15800:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.06824093388291143,    prediction: 0.07837679982185364
# index 15900:       inaccuracy: 14.853%
# -----------------------------------------------------------------
# target 0.05772726477475667,    prediction: 0.052163004875183105
# index 16000:       inaccuracy: 9.639%
# -----------------------------------------------------------------
# target 0.05003744623649217,    prediction: 0.04381948709487915
# index 16100:       inaccuracy: 12.427%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 16200:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.07659912555352016,    prediction: 0.03489997982978821
# index 16300:       inaccuracy: 54.438%
# -----------------------------------------------------------------
# target 0.029960899751481657,    prediction: 0.02954697608947754
# index 16400:       inaccuracy: 1.382%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 16500:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 16600:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.03428807892102077,    prediction: 0.03196287155151367
# index 16700:       inaccuracy: 6.781%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 16800:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 1.2440960542101478,    prediction: 1.1475367546081543
# index 16900:       inaccuracy: 7.761%
# -----------------------------------------------------------------
# target 0.030882712478366825,    prediction: 0.031152337789535522
# index 17000:       inaccuracy: 0.873%
# -----------------------------------------------------------------
# target 0.0500391883807146,    prediction: 0.03096523880958557
# index 17100:       inaccuracy: 38.118%
# -----------------------------------------------------------------
# target 0.18352558991720055,    prediction: 0.13798931241035461
# index 17200:       inaccuracy: 24.812%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 17300:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.03167153200569256,    prediction: 0.03253740072250366
# index 17400:       inaccuracy: 2.734%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 17500:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 17600:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.04386249392652476,    prediction: 0.0464196503162384
# index 17700:       inaccuracy: 5.83%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 17800:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 17900:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.03595756958278065,    prediction: 0.03655838966369629
# index 18000:       inaccuracy: 1.671%
# -----------------------------------------------------------------
# target 0.038338227905772355,    prediction: 0.04656386375427246
# index 18100:       inaccuracy: 21.455%
# -----------------------------------------------------------------
# target 0.06940450929952802,    prediction: 0.04449397325515747
# index 18200:       inaccuracy: 35.892%
# -----------------------------------------------------------------
# target 0.11491095122161804,    prediction: 0.13851022720336914
# index 18300:       inaccuracy: 20.537%
# -----------------------------------------------------------------
# target 0.2250120824906097,    prediction: 0.1784515380859375
# index 18400:       inaccuracy: 20.692%
# -----------------------------------------------------------------
# target 0.24650884841719423,    prediction: 0.1421888768672943
# index 18500:       inaccuracy: 42.319%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 18600:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.13179420226839908,    prediction: 0.19284072518348694
# index 18700:       inaccuracy: 46.32%
# -----------------------------------------------------------------
# target 0.03338816783867878,    prediction: 0.030775219202041626
# index 18800:       inaccuracy: 7.826%
# -----------------------------------------------------------------
# target 0.03122145263614258,    prediction: 0.03156694769859314
# index 18900:       inaccuracy: 1.107%
# -----------------------------------------------------------------
# target 0.033473412906991684,    prediction: 0.036694347858428955
# index 19000:       inaccuracy: 9.622%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 19100:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 19200:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.03794669182790603,    prediction: 0.03732985258102417
# index 19300:       inaccuracy: 1.626%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 19400:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 19500:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.085272827774255,    prediction: 0.09373804926872253
# index 19600:       inaccuracy: 9.927%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 19700:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.2885046638109246,    prediction: 0.18873095512390137
# index 19800:       inaccuracy: 34.583%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 19900:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.174365391062308,    prediction: 0.10506963729858398
# index 20000:       inaccuracy: 39.742%
# -----------------------------------------------------------------
# target 0.06426441692232775,    prediction: 0.08844247460365295
# index 20100:       inaccuracy: 37.623%
# -----------------------------------------------------------------
# target 0.06629961514972384,    prediction: 0.0831703245639801
# index 20200:       inaccuracy: 25.446%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 20300:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.05156905486967329,    prediction: 0.04462766647338867
# index 20400:       inaccuracy: 13.46%
# -----------------------------------------------------------------
# target 4.19934131790734,    prediction: 4.696325302124023
# index 20500:       inaccuracy: 11.835%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 20600:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.047566499389035045,    prediction: 0.03948518633842468
# index 20700:       inaccuracy: 16.99%
# -----------------------------------------------------------------
# target 0.03159681545450326,    prediction: 0.03672674298286438
# index 20800:       inaccuracy: 16.236%
# -----------------------------------------------------------------
# target 0.08360665951960014,    prediction: 0.1813952922821045
# index 20900:       inaccuracy: 116.963%
# -----------------------------------------------------------------
# target 0.5492897416010228,    prediction: 0.7884025573730469
# index 21000:       inaccuracy: 43.531%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 21100:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.03588506334192009,    prediction: 0.035076528787612915
# index 21200:       inaccuracy: 2.253%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 21300:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.10645062441574271,    prediction: 0.08597579598426819
# index 21400:       inaccuracy: 19.234%
# -----------------------------------------------------------------
# target 0.07827432595025872,    prediction: 0.08844247460365295
# index 21500:       inaccuracy: 12.99%
# -----------------------------------------------------------------
# target 0.03204665952428628,    prediction: 0.03484451770782471
# index 21600:       inaccuracy: 8.731%
# -----------------------------------------------------------------
# target 0.09318207908363058,    prediction: 0.060262054204940796
# index 21700:       inaccuracy: 35.329%
# -----------------------------------------------------------------
# target 0.10808873858750784,    prediction: 0.12941870093345642
# index 21800:       inaccuracy: 19.734%
# -----------------------------------------------------------------
# target 2.7149388427511236,    prediction: 4.567487716674805
# index 21900:       inaccuracy: 68.235%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 22000:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.04247708460962082,    prediction: 0.03952416777610779
# index 22100:       inaccuracy: 6.952%
# -----------------------------------------------------------------
# target 0.09400260250186383,    prediction: 0.10721257328987122
# index 22200:       inaccuracy: 14.053%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 22300:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.030832950395826793,    prediction: 0.0320640504360199
# index 22400:       inaccuracy: 3.993%
# -----------------------------------------------------------------
# target 0.07511860943536694,    prediction: 0.06572070717811584
# index 22500:       inaccuracy: 12.511%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 22600:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 22700:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.044111156538434906,    prediction: 0.04969823360443115
# index 22800:       inaccuracy: 12.666%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 22900:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.05764279176572117,    prediction: 0.047782182693481445
# index 23000:       inaccuracy: 17.106%
# -----------------------------------------------------------------
# target 0.05018038414435236,    prediction: 0.04676046967506409
# index 23100:       inaccuracy: 6.815%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 23200:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.21127690634993834,    prediction: 0.1633220613002777
# index 23300:       inaccuracy: 22.698%
# -----------------------------------------------------------------
# target 0.10855013032224521,    prediction: 0.1225176453590393
# index 23400:       inaccuracy: 12.867%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 23500:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.18471114136765898,    prediction: 0.06403151154518127
# index 23600:       inaccuracy: 65.334%
# -----------------------------------------------------------------
# target 0.21546761036835993,    prediction: 0.11726987361907959
# index 23700:       inaccuracy: 45.574%
# -----------------------------------------------------------------
# target 0.4791061263947055,    prediction: 0.43099743127822876
# index 23800:       inaccuracy: 10.041%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 23900:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 24000:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 24100:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.0708169625537888,    prediction: 0.06423833966255188
# index 24200:       inaccuracy: 9.29%
# -----------------------------------------------------------------
# target 0.13536056274736807,    prediction: 0.11006593704223633
# index 24300:       inaccuracy: 18.687%
# -----------------------------------------------------------------
# target 0.030642980670246338,    prediction: 0.03073972463607788
# index 24400:       inaccuracy: 0.316%
# -----------------------------------------------------------------
# target 0.029544410622695777,    prediction: 0.029445409774780273
# index 24500:       inaccuracy: 0.335%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 24600:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.08282865708518082,    prediction: 0.06501045823097229
# index 24700:       inaccuracy: 21.512%
# -----------------------------------------------------------------
# target 0.08589562200917092,    prediction: 0.07486042380332947
# index 24800:       inaccuracy: 12.847%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 24900:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.03148589391460608,    prediction: 0.03329470753669739
# index 25000:       inaccuracy: 5.745%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 25100:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 25200:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.08290994067588334,    prediction: 0.05425584316253662
# index 25300:       inaccuracy: 34.561%
# -----------------------------------------------------------------
# target 0.06105678985601916,    prediction: 0.047435909509658813
# index 25400:       inaccuracy: 22.309%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 25500:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.031586166159082,    prediction: 0.04086300730705261
# index 25600:       inaccuracy: 29.37%
# -----------------------------------------------------------------
# target 0.1442902379839663,    prediction: 0.1614762842655182
# index 25700:       inaccuracy: 11.911%
# -----------------------------------------------------------------
# target 0.13473819356128844,    prediction: 0.3252522349357605
# index 25800:       inaccuracy: 141.396%
# -----------------------------------------------------------------
# target 0.033804991558269964,    prediction: 0.03278455138206482
# index 25900:       inaccuracy: 3.019%
# -----------------------------------------------------------------
# target 0.03126199652168457,    prediction: 0.030457764863967896
# index 26000:       inaccuracy: 2.573%
# -----------------------------------------------------------------
# target 0.23011263519659056,    prediction: 0.18113824725151062
# index 26100:       inaccuracy: 21.283%
# -----------------------------------------------------------------
# target 0.10372577792004588,    prediction: 0.09988805651664734
# index 26200:       inaccuracy: 3.7%
# -----------------------------------------------------------------
# target 0.16337879728680013,    prediction: 0.23242124915122986
# index 26300:       inaccuracy: 42.259%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 26400:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.05609776165228637,    prediction: 0.03147086501121521
# index 26500:       inaccuracy: 43.9%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 26600:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.03805147462328624,    prediction: 0.03758683800697327
# index 26700:       inaccuracy: 1.221%
# -----------------------------------------------------------------
# target 0.11373938559158077,    prediction: 0.20542752742767334
# index 26800:       inaccuracy: 80.612%
# -----------------------------------------------------------------
# target 0.03879511107895968,    prediction: 0.03673902153968811
# index 26900:       inaccuracy: 5.3%
# -----------------------------------------------------------------
# target 0.06867521459501853,    prediction: 0.059558600187301636
# index 27000:       inaccuracy: 13.275%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 27100:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.05199798730392482,    prediction: 0.04545590281486511
# index 27200:       inaccuracy: 12.581%
# -----------------------------------------------------------------
# target 0.03558650178248273,    prediction: 0.03235936164855957
# index 27300:       inaccuracy: 9.068%
# -----------------------------------------------------------------
# target 0.030772499164906028,    prediction: 0.034589529037475586
# index 27400:       inaccuracy: 12.404%
# -----------------------------------------------------------------
# target 0.19550047251544173,    prediction: 0.2414267361164093
# index 27500:       inaccuracy: 23.492%
# -----------------------------------------------------------------
# target 0.07079163142881056,    prediction: 0.08844247460365295
# index 27600:       inaccuracy: 24.934%
# -----------------------------------------------------------------
# target 0.03028204358503329,    prediction: 0.03432127833366394
# index 27700:       inaccuracy: 13.339%
# -----------------------------------------------------------------
# target 0.4143929255099803,    prediction: 0.3219218850135803
# index 27800:       inaccuracy: 22.315%
# -----------------------------------------------------------------
# target 0.041203948860917945,    prediction: 0.03587234020233154
# index 27900:       inaccuracy: 12.94%
# -----------------------------------------------------------------
# target 0.24032289591808303,    prediction: 0.2088104784488678
# index 28000:       inaccuracy: 13.113%
# -----------------------------------------------------------------
# target 0.03318437472221228,    prediction: 0.031822800636291504
# index 28100:       inaccuracy: 4.103%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 28200:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.0436005755268708,    prediction: 0.04096972942352295
# index 28300:       inaccuracy: 6.034%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 28400:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.05341818115323365,    prediction: 0.05467808246612549
# index 28500:       inaccuracy: 2.359%
# -----------------------------------------------------------------
# target 0.0760137286532522,    prediction: 0.03864690661430359
# ...
# target 0.1464544246933479,    prediction: 0.21050390601158142
# index 46400:       inaccuracy: 43.733%
# -----------------------------------------------------------------
# target 0.35717864853166353,    prediction: 0.34964555501937866
# index 46500:       inaccuracy: 2.109%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 46600:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 46700:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.05327638894025711,    prediction: 0.03793516755104065
# index 46800:       inaccuracy: 28.796%
# -----------------------------------------------------------------
# target 0.035285703703366304,    prediction: 0.030958563089370728
# index 46900:       inaccuracy: 12.263%
# -----------------------------------------------------------------
# target 0.25969880161175596,    prediction: 0.25039103627204895
# index 47000:       inaccuracy: 3.584%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 47100:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 47200:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.036950581058752485,    prediction: 0.04893425107002258
# index 47300:       inaccuracy: 32.432%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 47400:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 1.9075315226123817,    prediction: 1.1367827653884888
# index 47500:       inaccuracy: 40.406%
# -----------------------------------------------------------------
# target 0.03209742684572686,    prediction: 0.03145226836204529
# index 47600:       inaccuracy: 2.01%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 47700:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.057370176863378926,    prediction: 0.04188010096549988
# index 47800:       inaccuracy: 27.0%
# -----------------------------------------------------------------
# target 0.03712811610745661,    prediction: 0.034589529037475586
# index 47900:       inaccuracy: 6.837%
# -----------------------------------------------------------------
# target 0.04045745270547489,    prediction: 0.035945355892181396
# index 48000:       inaccuracy: 11.153%
# -----------------------------------------------------------------
# target 0.030180017813900454,    prediction: 0.029766619205474854
# index 48100:       inaccuracy: 1.37%
# -----------------------------------------------------------------
# target 0.1670557665854032,    prediction: 0.14388981461524963
# index 48200:       inaccuracy: 13.867%
# -----------------------------------------------------------------
# target 0.3191603690378784,    prediction: 0.2808196246623993
# index 48300:       inaccuracy: 12.013%
# -----------------------------------------------------------------
# target 0.04779044738827155,    prediction: 0.051408976316452026
# index 48400:       inaccuracy: 7.572%
# -----------------------------------------------------------------
# target 0.03038242529911496,    prediction: 0.031165480613708496
# index 48500:       inaccuracy: 2.577%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 48600:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 2.6478522301815466,    prediction: 1.3503215312957764
# index 48700:       inaccuracy: 49.003%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 48800:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 48900:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.08726673319899866,    prediction: 0.07096770405769348
# index 49000:       inaccuracy: 18.677%
# -----------------------------------------------------------------
# target 0.2861631183572561,    prediction: 0.1484105885028839
# index 49100:       inaccuracy: 48.138%
# -----------------------------------------------------------------
# target 0.03424185990623059,    prediction: 0.03203892707824707
# index 49200:       inaccuracy: 6.433%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 49300:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.1701478210157232,    prediction: 0.2063661515712738
# index 49400:       inaccuracy: 21.286%
# -----------------------------------------------------------------
# target 0.034502164774790456,    prediction: 0.031643450260162354
# index 49500:       inaccuracy: 8.286%
# -----------------------------------------------------------------
# target 0.06373742444472154,    prediction: 0.19594520330429077
# index 49600:       inaccuracy: 207.426%
# -----------------------------------------------------------------
# target 0.10142590951472269,    prediction: 0.06185641884803772
# index 49700:       inaccuracy: 39.013%
# -----------------------------------------------------------------
# target 0.0607501328072513,    prediction: 0.04031246900558472
# index 49800:       inaccuracy: 33.642%
# -----------------------------------------------------------------
# target 0.22743124404408865,    prediction: 0.44186079502105713
# index 49900:       inaccuracy: 94.283%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 50000:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 50100:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 50200:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.35133624732172514,    prediction: 0.23219776153564453
# index 50300:       inaccuracy: 33.91%
# -----------------------------------------------------------------
# target 0.03469346899821159,    prediction: 0.040639728307724
# index 50400:       inaccuracy: 17.139%
# -----------------------------------------------------------------
# target 0.052562631744892244,    prediction: 0.04053550958633423
# index 50500:       inaccuracy: 22.882%
# -----------------------------------------------------------------
# target 0.03457778605809194,    prediction: 0.03301098942756653
# index 50600:       inaccuracy: 4.531%
# -----------------------------------------------------------------
# target 0.03821536544657902,    prediction: 0.03382489085197449
# index 50700:       inaccuracy: 11.489%
# -----------------------------------------------------------------
# target 0.0383733436518665,    prediction: 0.03483244776725769
# index 50800:       inaccuracy: 9.227%
# -----------------------------------------------------------------
# target 0.3336417730474316,    prediction: 0.3853917121887207
# index 50900:       inaccuracy: 15.511%
# -----------------------------------------------------------------
# target 0.07996899651671366,    prediction: 0.11529526114463806
# index 51000:       inaccuracy: 44.175%
# -----------------------------------------------------------------
# target 0.03485215962838179,    prediction: 0.03218570351600647
# index 51100:       inaccuracy: 7.651%
# -----------------------------------------------------------------
# target 0.043839277752583984,    prediction: 0.03875771164894104
# index 51200:       inaccuracy: 11.591%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 51300:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.031138488613298845,    prediction: 0.03165900707244873
# index 51400:       inaccuracy: 1.672%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 51500:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.057321251178335225,    prediction: 0.0521598756313324
# index 51600:       inaccuracy: 9.004%
# -----------------------------------------------------------------
# target 0.0933991882292515,    prediction: 0.1588141918182373
# index 51700:       inaccuracy: 70.038%
# -----------------------------------------------------------------
# target 0.16945640485612284,    prediction: 0.08517757058143616
# index 51800:       inaccuracy: 49.735%
# -----------------------------------------------------------------
# target 0.08239763241531042,    prediction: 0.11019352078437805
# index 51900:       inaccuracy: 33.734%
# -----------------------------------------------------------------
# target 0.04566902095295605,    prediction: 0.04321938753128052
# index 52000:       inaccuracy: 5.364%
# -----------------------------------------------------------------
# target 0.03500957712660641,    prediction: 0.034589529037475586
# index 52100:       inaccuracy: 1.2%
# -----------------------------------------------------------------
# target 0.09343401254550329,    prediction: 0.0830906331539154
# index 52200:       inaccuracy: 11.07%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 52300:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.06981603743802307,    prediction: 0.04173734784126282
# index 52400:       inaccuracy: 40.218%
# -----------------------------------------------------------------
# target 0.03595202221674344,    prediction: 0.03466174006462097
# index 52500:       inaccuracy: 3.589%
# -----------------------------------------------------------------
# target 0.066750417629816,    prediction: 0.06604042649269104
# index 52600:       inaccuracy: 1.064%
# -----------------------------------------------------------------
# target 0.029880010262520115,    prediction: 0.031213343143463135
# index 52700:       inaccuracy: 4.462%
# -----------------------------------------------------------------
# target 0.11468772122554688,    prediction: 0.07961684465408325
# index 52800:       inaccuracy: 30.579%
# -----------------------------------------------------------------
# target 0.03595202221674344,    prediction: 0.03466174006462097
# index 52900:       inaccuracy: 3.589%
# -----------------------------------------------------------------
# target 0.0725993824159006,    prediction: 0.05315542221069336
# index 53000:       inaccuracy: 26.783%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 53100:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.03686832975951564,    prediction: 0.04669436812400818
# index 53200:       inaccuracy: 26.652%
# -----------------------------------------------------------------
# target 0.05021184373548455,    prediction: 0.05366814136505127
# index 53300:       inaccuracy: 6.883%
# -----------------------------------------------------------------
# target 0.05908115500299997,    prediction: 0.06864643096923828
# index 53400:       inaccuracy: 16.19%
# -----------------------------------------------------------------
# target 0.030848143590547123,    prediction: 0.033594876527786255
# index 53500:       inaccuracy: 8.904%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 53600:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 53700:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.14273255921559916,    prediction: 0.13090136647224426
# index 53800:       inaccuracy: 8.289%
# -----------------------------------------------------------------
# target 0.19431550310905474,    prediction: 0.2586970925331116
# index 53900:       inaccuracy: 33.133%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 54000:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.034972595730803746,    prediction: 0.03785741329193115
# index 54100:       inaccuracy: 8.249%
# -----------------------------------------------------------------
# target 0.046108447571287604,    prediction: 0.05515223741531372
# index 54200:       inaccuracy: 19.614%
# -----------------------------------------------------------------
# target 0.06458994689841645,    prediction: 0.04859822988510132
# index 54300:       inaccuracy: 24.759%
# -----------------------------------------------------------------
# target 0.06984263906202179,    prediction: 0.048389434814453125
# index 54400:       inaccuracy: 30.716%
# -----------------------------------------------------------------
# target 0.4492542297425122,    prediction: 0.2370566874742508
# index 54500:       inaccuracy: 47.233%
# -----------------------------------------------------------------
# target 0.11108150034129363,    prediction: 0.14927923679351807
# index 54600:       inaccuracy: 34.387%
# -----------------------------------------------------------------
# target 0.035284727385139394,    prediction: 0.03414139151573181
# index 54700:       inaccuracy: 3.24%
# -----------------------------------------------------------------
# target 0.0725232429370666,    prediction: 0.06815114617347717
# index 54800:       inaccuracy: 6.029%
# -----------------------------------------------------------------
# target 0.04256854900010931,    prediction: 0.07472917437553406
# index 54900:       inaccuracy: 75.55%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 55000:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.18014043751109038,    prediction: 0.28514620661735535
# index 55100:       inaccuracy: 58.291%
# -----------------------------------------------------------------
# target 0.11376857283680192,    prediction: 0.07317718863487244
# index 55200:       inaccuracy: 35.679%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 55300:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.05890568156065557,    prediction: 0.09204009175300598
# index 55400:       inaccuracy: 56.25%
# -----------------------------------------------------------------
# target 2.126286792785974,    prediction: 2.670372247695923
# index 55500:       inaccuracy: 25.589%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 55600:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 55700:       inaccuracy: 2.148%
# -----------------------------------------------------------------
# target 0.028653960184055832,    prediction: 0.029269516468048096
# index 55800:       inaccuracy: 2.148%
# -----------------------------------------------------------------

# %%
print("Average inaccuracy: ", np.round(sum(errors)/len(errors), 3))
# Out:
# Average inaccuracy:  19.425

# %%
torch.save(model, "trained_FFNN_pagerank_epinions_discounted0.pt")
